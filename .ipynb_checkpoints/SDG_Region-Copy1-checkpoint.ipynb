# %%
import pandas as pd
import matplotlib.pyplot as plt

da = pd.read_csv('SD_Report_2023.csv', index_col=0)

sd_data=pd.DataFrame(data)

#1)BY REGION--------------------------------------------------

#print(sd_data)
sd_meandata= sd_data.groupby(['Region']).mean(['Overall_Score'])

data=sd_meandata.get(['Overall_Score'])
#print(sd_meandata)

#-------------------------Plot--------------------------------

#Getting the values for the column we need. Array format

#Extract the Regionn list an as object
x= data.index.tolist()
#How to get the values of a pandas DataFrame variable as a list objec
y= data['Overall_Score'].tolist()
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange', 'tab:green']



fig, ax = plt.subplots()
ax.bar(x, y, width=0.9, edgecolor="white", linewidth=0.7, color=bar_colors)

ax.set_ylabel("Overall Score", loc='center')
ax.set_title("Average overall score in the SDG framework per Region")
ax.legend(title="Overall Score")


#1)BY EU COUNTRY IN OCDE---------------------------------------------
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
